# %% [markdown]
# # Моделирование: рекомендации банковских продуктов
#
# Обучаем 24 бинарных LightGBM-модели (по одной на продукт), сравниваем с popularity baseline, логируем эксперимент в MLflow.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

assert (ROOT / "src").exists(), f"Не найден src/. Запустите Jupyter из корня проекта или из notebooks/"
print("Project root:", ROOT)
# Out:
# Project root: /home/mle-user/mle-bank-recommendations

# %%
import json
from pathlib import Path

from src.config import ARTIFACTS_DIR, ROOT
from src.train import run_training

metrics = run_training()
print(json.dumps(metrics, indent=2))
print("MLflow DB:", ROOT / "mlflow.db")
print("Model:", ROOT / "models" / "recommender.pkl")
print("Metrics file:", ARTIFACTS_DIR / "metrics.json")
# Out:
# /home/mle-user/.local/lib/python3.10/site-packages/pydantic/_internal/_config.py:383: UserWarning: Valid config keys have changed in V2:
# * 'schema_extra' has been renamed to 'json_schema_extra'
#   warnings.warn(message, UserWarning)
# Building train dataset...
# Train rows: 400000
# Building validation dataset...
# Validation rows: 200000
# Baseline: {'map@7': 0.5426126469900039, 'precision@7': 0.004491428571428571, 'recall@7': 0.9033110501656954, 'coverage@7': 0.2916666666666667}
#   training 1/24: ind_ahor_fin_ult1
#   training 2/24: ind_aval_fin_ult1
#   training 3/24: ind_cco_fin_ult1
#   training 4/24: ind_cder_fin_ult1
#   training 5/24: ind_cno_fin_ult1
#   training 6/24: ind_ctju_fin_ult1
#   training 7/24: ind_ctma_fin_ult1
#   training 8/24: ind_ctop_fin_ult1
#   training 9/24: ind_ctpp_fin_ult1
#   training 10/24: ind_deco_fin_ult1
#   training 11/24: ind_deme_fin_ult1
#   training 12/24: ind_dela_fin_ult1
#   training 13/24: ind_ecue_fin_ult1
# ...

# %%
metrics = json.loads((ARTIFACTS_DIR / "metrics.json").read_text(encoding="utf-8"))
metrics
# Out:
# {'map@7': 0.7446135883790153,
#  'precision@7': 0.004635714285714285,
#  'recall@7': 0.9344360644497771,
#  'coverage@7': 1.0}
